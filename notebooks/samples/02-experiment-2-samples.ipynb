# %%
import sys

import torch

sys.path.append("../../")
from src import Generator, AutoDiffusionPipeline
# Out:
# /home/shahinshah/.pyenv/versions/3.10.13/envs/torch-env/lib/python3.10/site-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)

# %%
model_log_dir = "../../model_logs/experiment2/deep_fashion"

# %%
rank1_restore_version = "train_240404194859"
rank2_restore_version = "train_240405090216"
rank4_restore_version = "train_240425172459"
rank8_restore_version = "train_240426203100"
rank64_restore_version = "train_240427101135"

# %%
rank1_generator = Generator.for_pretrained_lora(model_log_dir, rank1_restore_version, dtype=torch.float16, enable_xformers=True, refiner_name="stabilityai/stable-diffusion-xl-refiner-1.0")
rank2_generator = Generator.for_pretrained_lora(model_log_dir, rank2_restore_version, dtype=torch.float16, enable_xformers=True, refiner_name="stabilityai/stable-diffusion-xl-refiner-1.0")
rank4_generator = Generator.for_pretrained_lora(model_log_dir, rank4_restore_version, dtype=torch.float16, enable_xformers=True, refiner_name="stabilityai/stable-diffusion-xl-refiner-1.0")
rank8_generator = Generator.for_pretrained_lora(model_log_dir, rank8_restore_version, dtype=torch.float16, enable_xformers=True, refiner_name="stabilityai/stable-diffusion-xl-refiner-1.0")
rank64_generator = Generator.for_pretrained_lora(model_log_dir, rank64_restore_version, dtype=torch.float16, enable_xformers=True, refiner_name="stabilityai/stable-diffusion-xl-refiner-1.0")
rank1_generator.to("cuda:0")
rank2_generator.to("cuda:0")
rank4_generator.to("cuda:0")
rank8_generator.to("cuda:1")
rank64_generator.to("cuda:1")
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# # Sample 1

# %%
prompt = "This man wears a long-sleeve shirt with color block patterns. The shirt is with cotton fabric and its neckline is lapel."
seed = 0
best_of_n = 1
guidance_scale = 5

# %%
rank1_images = rank1_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank1_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank2_images = rank2_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank2_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank4_images = rank4_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank4_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank8_images = rank8_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank8_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank64_images = rank64_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank64_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %% [markdown]
# # Sample 2

# %%
prompt = "The shirt the lady wears has medium sleeves and its fabric is cotton. It has a v-shape neckline."
seed = 30
best_of_n = 1
guidance_scale = 5

# %%
rank1_images = rank1_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank1_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank2_images = rank2_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank2_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank4_images = rank4_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank4_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank8_images = rank8_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank8_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank64_images = rank64_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank64_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %% [markdown]
# # Sample 3

# %%
prompt = "The sweater this man wears has long sleeves and it is with cotton fabric and solid color patterns."
seed = 30
best_of_n = 1
guidance_scale = 5

# %%
rank1_images = rank1_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank1_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank2_images = rank2_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank2_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank4_images = rank4_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank4_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank8_images = rank8_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank8_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>

# %%
rank64_images = rank64_generator(prompt, best_of_n, seed, refine_frac=0.2, height=512, width=360, guidance_scale=guidance_scale)
rank64_images[0]
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=360x512>
