# %%
import sys

import torch

sys.path.append("../..")
from src import Generator, AutoDiffusionPipeline
# Out:
# /home/shahinshah/.pyenv/versions/3.10.13/envs/torch-env/lib/python3.10/site-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)

# %%
model_log_dir = "../../model_logs/experiment5"
restore_version = "train_240727142109"

# %%
lora_generator = Generator.for_pretrained_lora(model_log_dir, restore_version, best_or_last="last", dtype=torch.float16, enable_xformers=True, refiner_name="stabilityai/stable-diffusion-xl-refiner-1.0")
lora_generator.to("cuda:0")
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# # Sample 1

# %%
prompt = "A high-quality image of a professional photoshoot featuring a woman wearing an sks pants with ukj colour."
seed = 100
best_of_n = 1

# %%
lora_images = lora_generator(prompt, best_of_n, seed, refine_frac=0.2, height=1024, width=760, guidance_scale=5)
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
lora_images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=760x1024>

# %% [markdown]
# # Sample 2

# %%
prompt = "A high-quality image of a professional photoshoot featuring a woman wearing an sks pants with ukj colour, looking from back."
seed = 100
best_of_n = 1

# %%
lora_images = lora_generator(prompt, best_of_n, seed, refine_frac=0.2, height=1024, width=760, guidance_scale=5)
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
lora_images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=760x1024>

# %% [markdown]
# # Sample 3

# %%
prompt = "A high-quality image of a professional photoshoot featuring a man wearing an sks pants with ukj colour."
seed = 100
best_of_n = 1

# %%
lora_images = lora_generator(prompt, best_of_n, seed, refine_frac=0.2, height=1024, width=760, guidance_scale=5)
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
lora_images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=760x1024>
